# %% [markdown]
# ### Scenario 1: A single data scientist participating in an ML competition
#
# MLFlow setup:
# * Tracking server: no
# * Backend store: local filesystem
# * Artifacts store: local filesystem

# %%
import mlflow
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score
from mlflow.tracking import MlflowClient

print(f"Tracking URI: {mlflow.get_tracking_uri()}")
# Out:
# Tracking URI: file:///c:/Users/urbii/Desktop/Projekty/mlops-zoomcamp/02-experiment-tracking/running-mlflow-examples/mlruns

# %%
import mlflow.experiments


mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='file:///c:/Users/urbii/Desktop/Projekty/mlops-zoomcamp/02-experiment-tracking/running-mlflow-examples/mlruns/0', creation_time=1720135725528, experiment_id='0', last_update_time=1720135725528, lifecycle_stage='active', name='Default', tags={}>]

# %% [markdown]
# ### Creating an experiment and logging a new run

# %%
mlflow.set_experiment("my-experiment-1")

with mlflow.start_run():

    X, y = load_iris(return_X_y=True)

    params = {"C": 0.1, "random_state": 42}
    mlflow.log_params(params)

    lr = LogisticRegression(**params).fit(X, y)
    y_pred = lr.predict(X)
    mlflow.log_metric("accuracy", accuracy_score(y, y_pred))

    mlflow.sklearn.log_model(lr, artifact_path="models")
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
# Out:
# 2024/07/05 01:31:09 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# default artifacts URI: 'file:///c:/Users/urbii/Desktop/Projekty/mlops-zoomcamp/02-experiment-tracking/running-mlflow-examples/mlruns/341464529541035123/bf91c08f60724cc9bc247b69ba8135ef/artifacts'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='file:///c:/Users/urbii/Desktop/Projekty/mlops-zoomcamp/02-experiment-tracking/running-mlflow-examples/mlruns/341464529541035123', creation_time=1720135869815, experiment_id='341464529541035123', last_update_time=1720135869815, lifecycle_stage='active', name='my-experiment-1', tags={}>,
#  <Experiment: artifact_location='file:///c:/Users/urbii/Desktop/Projekty/mlops-zoomcamp/02-experiment-tracking/running-mlflow-examples/mlruns/0', creation_time=1720135725528, experiment_id='0', last_update_time=1720135725528, lifecycle_stage='active', name='Default', tags={}>]
